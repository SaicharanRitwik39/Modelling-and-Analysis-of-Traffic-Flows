# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from mpl_toolkits.mplot3d import Axes3D

# %%
beta = 0.01      #Behaviour of all the vehicles with inflow, ouflow and blockings.
r2 = 0.5
tau = 40
mud = 0.1
gamma = 0.7

def f(state, t):
    x, y, z = state  # Unpack the state vector
    return tau-beta*x*y-mud*x+r2*z, beta*x*y-mud*y-gamma*y, gamma*y-mud*z-r2*z  # Derivatives

state0 = [80, 247, 287]
t = np.arange(0.0, 40.0, 0.01)

states = odeint(f, state0, t)

fig = plt.figure()
ax = fig.gca(projection="3d")
ax.plot(states[:, 0], states[:, 1], states[:, 2])
ax.set_xlabel('$F$')
ax.set_ylabel('$B$')
ax.set_zlabel('$D$')
plt.draw()
plt.show()

# %%
beta = 0.01      #Behaviour of all the vehicles with inflow, ouflow and blockings.
r2 = 0.5
tau = 40
mud = 0.1
gamma = 0.7

def f(state, t):
    x, y, z = state  # Unpack the state vector
    return tau-beta*x*y-mud*x+r2*z, beta*x*y-mud*y-gamma*y, gamma*y-mud*z-r2*z  # Derivatives

state0 = [60, 180, 70]
t = np.arange(0.0, 40.0, 0.01)

states = odeint(f, state0, t)

fig = plt.figure()
ax = fig.gca(projection="3d")
ax.plot(states[:, 0], states[:, 1], states[:, 2])
ax.set_xlabel('$F$')
ax.set_ylabel('$B$')
ax.set_zlabel('$D$')
plt.draw()
plt.show()

# %%
beta = 0.01      #Behaviour of all the vehicles with inflow, ouflow and blockings.
r2 = 0.5
tau = 40
mud = 0.1
gamma = 0.7

def f(state, t):
    x, y, z = state  # Unpack the state vector
    return tau-beta*x*y-mud*x+r2*z, beta*x*y-mud*y-gamma*y, gamma*y-mud*z-r2*z  # Derivatives

state0 = [40, 180, 70]
t = np.arange(0.0, 40.0, 0.01)

states = odeint(f, state0, t)

fig = plt.figure()
ax = fig.gca(projection="3d")
ax.plot(states[:, 0], states[:, 1], states[:, 2])
ax.set_xlabel('$F$')
ax.set_ylabel('$B$')
ax.set_zlabel('$D$')
plt.draw()
plt.show()

# %%
beta = 0.01      #Behaviour of all the vehicles with inflow, ouflow and blockings.
r2 = 0.5
tau = 40
mud = 0.1
gamma = 0.7

def f(state, t):
    x, y, z = state  # Unpack the state vector
    return tau-beta*x*y-mud*x+r2*z, beta*x*y-mud*y-gamma*y, gamma*y-mud*z-r2*z  # Derivatives

state0 = [0, 180, 70]
t = np.arange(0.0, 40.0, 0.01)

states = odeint(f, state0, t)

fig = plt.figure()
ax = fig.gca(projection="3d")
ax.plot(states[:, 0], states[:, 1], states[:, 2])
ax.set_xlabel('$F$')
ax.set_ylabel('$B$')
ax.set_zlabel('$D$')
plt.draw()
plt.show()

# %%
beta = 0.01      #Behaviour of all the vehicles with inflow, ouflow and blockings.
r2 = 0.5
tau = 40
mud = 0.1
gamma = 0.7

def f(state, t):
    x, y, z = state  # Unpack the state vector
    return tau-beta*x*y-mud*x+r2*z, beta*x*y-mud*y-gamma*y, gamma*y-mud*z-r2*z  # Derivatives

state0 = [80, 160, 70]
t = np.arange(0.0, 40.0, 0.01)

states = odeint(f, state0, t)

fig = plt.figure()
ax = fig.gca(projection="3d")
ax.plot(states[:, 0], states[:, 1], states[:, 2])
ax.set_xlabel('$F$')
ax.set_ylabel('$B$')
ax.set_zlabel('$D$')
plt.draw()
plt.show()

# %%
beta = 0.01      #Behaviour of all the vehicles with inflow, ouflow and blockings.
r2 = 0.5
tau = 40
mud = 0.1
gamma = 0.7

def f(state, t):
    x, y, z = state  # Unpack the state vector
    return tau-beta*x*y-mud*x+r2*z, beta*x*y-mud*y-gamma*y, gamma*y-mud*z-r2*z  # Derivatives

state0 = [80, 120, 70]
t = np.arange(0.0, 40.0, 0.01)

states = odeint(f, state0, t)

fig = plt.figure()
ax = fig.gca(projection="3d")
ax.plot(states[:, 0], states[:, 1], states[:, 2])
ax.set_xlabel('$F$')
ax.set_ylabel('$B$')
ax.set_zlabel('$D$')
plt.draw()
plt.show()

# %%
beta = 0.01      #Behaviour of all the vehicles with inflow, ouflow and blockings.
r2 = 0.5
tau = 40
mud = 0.1
gamma = 0.7

def f(state, t):
    x, y, z = state  # Unpack the state vector
    return tau-beta*x*y-mud*x+r2*z, beta*x*y-mud*y-gamma*y, gamma*y-mud*z-r2*z  # Derivatives

state0 = [80, 80, 70]
t = np.arange(0.0, 40.0, 0.01)

states = odeint(f, state0, t)

fig = plt.figure()
ax = fig.gca(projection="3d")
ax.plot(states[:, 0], states[:, 1], states[:, 2])
ax.set_xlabel('$F$')
ax.set_ylabel('$B$')
ax.set_zlabel('$D$')
plt.draw()
plt.show()
